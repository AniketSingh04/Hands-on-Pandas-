# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Getting Started**

# %%
df = pd.read_csv("survey_results_public.csv")

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
schema_df = pd.read_csv("survey_results_schema.csv")

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.head(3)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %%
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.tail(7)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88876  OSS is, on average, of HIGHER quality than pro...
# 88877  The quality of OSS and closed source software ...
# ...

# %% [markdown]
# **DataFrame and Series Basics**

# %%
people = {
    "first" : ['aniket','akhil','prateek'],
    "last" : ['singh','kumar','shrivastav'],
    "email" : ['aniketrajsingh29@gmail.com','akhilkumar123@gmail.com','iamprateek456@gmail.com']
}

# %%
df  = pd.DataFrame(people)

# %%
df
# Out:
#      first        last                       email
# 0   aniket       singh  aniketrajsingh29@gmail.com
# 1    akhil       kumar     akhilkumar123@gmail.com
# 2  prateek  shrivastav     iamprateek456@gmail.com

# %%
df['email']
# Out:
# 0    aniketrajsingh29@gmail.com
# 1       akhilkumar123@gmail.com
# 2       iamprateek456@gmail.com
# Name: email, dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
df[['last','email']]
# Out:
#          last                       email
# 0       singh  aniketrajsingh29@gmail.com
# 1       kumar     akhilkumar123@gmail.com
# 2  shrivastav     iamprateek456@gmail.com

# %%
type(df[['last','email']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.iloc[[0,1],2]
# Out:
# 0    aniketrajsingh29@gmail.com
# 1       akhilkumar123@gmail.com
# Name: email, dtype: object

# %%
df
# Out:
#      first        last                       email
# 0   aniket       singh  aniketrajsingh29@gmail.com
# 1    akhil       kumar     akhilkumar123@gmail.com
# 2  prateek  shrivastav     iamprateek456@gmail.com

# %%
df.loc[0]
# Out:
# first                        aniket
# last                          singh
# email    aniketrajsingh29@gmail.com
# Name: 0, dtype: object

# %%
df.loc[[1,0],['email','last']]
# Out:
#                         email   last
# 1     akhilkumar123@gmail.com  kumar
# 0  aniketrajsingh29@gmail.com  singh

# %%
df = pd.read_csv("survey_results_public.csv")

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[0:8,'Hobbyist':'Employment']
# Out:
#   Hobbyist                 OpenSourcer  \
# 0      Yes                       Never
# 1       No     Less than once per year
# 2      Yes                       Never
# 3       No                       Never
# 4      Yes  Once a month or more often
# 5      Yes                       Never
# 6       No                       Never
# 7      Yes     Less than once per year
# 8      Yes  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
# 5  The quality of OSS and closed source software ...
# 6  The quality of OSS and closed source software ...
# 7  OSS is, on average, of HIGHER quality than pro...
# 8  The quality of OSS and closed source software ...
#
# ...

# %% [markdown]
# **Indexes- Set, Reset and Use**

# %%
people = {
    "first" : ['aniket','akhil','prateek'],
    "last" : ['singh','kumar','shrivastav'],
    "email" : ['aniketrajsingh29@gmail.com','akhilkumar123@gmail.com','iamprateek456@gmail.com']
}
df = pd.DataFrame(people)

# %%
df
# Out:
#      first        last                       email
# 0   aniket       singh  aniketrajsingh29@gmail.com
# 1    akhil       kumar     akhilkumar123@gmail.com
# 2  prateek  shrivastav     iamprateek456@gmail.com

# %%
df.set_index('email',inplace=True)

# %%
df
# Out:
#                               first        last
# email
# aniketrajsingh29@gmail.com   aniket       singh
# akhilkumar123@gmail.com       akhil       kumar
# iamprateek456@gmail.com     prateek  shrivastav

# %%
df.index
# Out:
# Index(['aniketrajsingh29@gmail.com', 'akhilkumar123@gmail.com',
#        'iamprateek456@gmail.com'],
#       dtype='object', name='email')

# %%
df.loc['aniketrajsingh29@gmail.com','last']
# Out:
# 'singh'

# %%
people = {
    "first" : ['aniket','akhil','prateek'],
    "last" : ['singh','kumar','shrivastav'],
    "email" : ['aniketrajsingh29@gmail.com','akhilkumar123@gmail.com','iamprateek456@gmail.com']
}
df = pd.DataFrame(people)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.set_index('email',inplace=True)

# %%
df
# Out:
#                               first        last
# email
# aniketrajsingh29@gmail.com   aniket       singh
# akhilkumar123@gmail.com       akhil       kumar
# iamprateek456@gmail.com     prateek  shrivastav

# %%
df.index
# Out:
# Index(['aniketrajsingh29@gmail.com', 'akhilkumar123@gmail.com',
#        'iamprateek456@gmail.com'],
#       dtype='object', name='email')

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                         email    first        last
# 0  aniketrajsingh29@gmail.com   aniket       singh
# 1     akhilkumar123@gmail.com    akhil       kumar
# 2     iamprateek456@gmail.com  prateek  shrivastav

# %%
df = pd.read_csv("survey_results_public.csv", index_col = 'Respondent')
schema_df = pd.read_csv("survey_results_schema.csv",index_col='Column')
pd.set_option('display.max_columns',85)

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
df.loc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
schema_df.loc['JobSat']
# Out:
# QuestionText    How satisfied are you with your current job? (...
# Name: JobSat, dtype: object

# %%
schema_df.sort_index()
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %% [markdown]
# **Filtering**

# %%
df = pd.read_csv("survey_results_public.csv", index_col = 'Respondent')
schema_df = pd.read_csv("survey_results_schema.csv",index_col='Column')
pd.set_option('display.max_columns',85)

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema_df.reset_index(inplace=True)

# %%
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema_df.loc["ConvertedComp"]
# Out:
# QuestionText    Salary converted to annual USD salaries using ...
# Name: ConvertedComp, dtype: object

# %%
high_salary = (df["ConvertedComp"] > 70000)

# %%
df.loc[high_salary,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States','India','United Kingdom','Germany','Canada']
filt = df['Country'].isin(countries)

# %%
df['Country'].isin(countries)
# Out:
# Respondent
# 1         True
# 2        False
# 3        False
# 4         True
# 5        False
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: Country, Length: 88883, dtype: bool

# %%
df.loc[filt,'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
filt2 = df['LanguageWorkedWith'].isin(['Python','Java'])

# %%
df.loc[filt2,['Country','LanguageWorkedWith']]
# Out:
#                        Country LanguageWorkedWith
# Respondent
# 31                      Canada             Python
# 45               United States             Python
# 131                  Australia               Java
# 207         Hong Kong (S.A.R.)               Java
# 309                     Israel               Java
# ...                        ...                ...
# 36319                     Iraq               Java
# 48134                   Turkey             Python
# 54777            United States             Python
# 61787                   Israel             Python
# 81922       Russian Federation               Java
#
# [1693 rows x 2 columns]

# %%
filt3 = df["LanguageWorkedWith"].str.contains('Java',na=False)

# %%
df.loc[filt3,"LanguageWorkedWith"]
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 6                                               Java;R;SQL
# 7                                      HTML/CSS;JavaScript
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88182                             HTML/CSS;Java;JavaScript
# 88212                           HTML/CSS;JavaScript;Python
# 88282    Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 70113, dtype: object

# %% [markdown]
# **Updating Rows and Columns**

# %%
df = pd.read_csv("survey_results_public.csv", index_col = 'Respondent')
schema_df = pd.read_csv("survey_results_schema.csv",index_col='Column')

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
df.rename(columns = {'ConvertedComp': 'SalaryUSD'},inplace=True)

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist']=df['Hobbyist'].map({'Yes':'True','No':'False'})

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code     True
# 2                      I am a student who is learning to code    False
# 3           I am not primarily a developer, but I write co...     True
# 4                              I am a developer by profession    False
# 5                              I am a developer by profession     True
# ...                                                       ...      ...
# 88377                                                     NaN     True
# 88601                                                     NaN    False
# 88802                                                     NaN    False
# 88816                                                     NaN    False
# 88863                                                     NaN     True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# **Sorting Data**

# %%
df.sort_values(by=['Country','SalaryUSD'],ascending=[True,False],inplace =True)

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 63129                          I am a developer by profession     True
# 50499       I am not primarily a developer, but I write co...     True
# 39258                          I am a developer by profession     True
# 58450                          I am a developer by profession     True
# 7085                           I am a developer by profession     True
# ...                                                       ...      ...
# 88062                                                     NaN    False
# 88076                                                     NaN    False
# 88601                                                     NaN    False
# 88802                                                     NaN    False
# 88816                                                     NaN    False
#
#                         OpenSourcer  \
# Respondent
# 63129                         Never
# ...

# %%
df.tail()
# Out:
#            MainBranch Hobbyist OpenSourcer  \
# Respondent
# 88062             NaN    False       Never
# 88076             NaN    False       Never
# 88601             NaN    False       Never
# 88802             NaN    False       Never
# 88816             NaN    False       Never
#
#                                                    OpenSource  \
# Respondent
# 88062       OSS is, on average, of LOWER quality than prop...
# 88076       OSS is, on average, of HIGHER quality than pro...
# 88601       The quality of OSS and closed source software ...
# 88802                                                     NaN
# 88816       OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment Country Student  \
# Respondent
# 88062                                                     NaN     NaN     NaN
# 88076                                      Employed full-time     NaN     NaN
# ...

# %%
df.head(10)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 39258               I am a developer by profession     True
# 63129               I am a developer by profession     True
# 85715               I am a developer by profession    False
# 50767               I am a developer by profession    False
# 2782                                           NaN     True
# 63019                                          NaN    False
# 6417        I am a student who is learning to code     True
# 40000       I am a student who is learning to code     True
# 88731                  I code primarily as a hobby     True
# 48436               I am a developer by profession    False
#
#                                                   OpenSourcer  \
# Respondent
# 39258                                 Less than once per year
# 63129                                                   Never
# 85715                                 Less than once per year
# ...

# %%
df[['Country','SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10,'SalaryUSD')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 25983                          I am a developer by profession     True
# 87896                          I am a developer by profession     True
# 22013                          I am a developer by profession     True
# 28243                          I am a developer by profession     True
# 72732       I am not primarily a developer, but I write co...    False
# 78151                          I am a developer by profession     True
# 80200                          I am a developer by profession     True
# 52132                          I am a developer by profession     True
# 75561                          I am a developer by profession     True
# 32250                          I am a developer by profession     True
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %% [markdown]
# **Grouping and Aggregating - Analyzing and Exploring Your Data**

# %% [markdown]
# df = pd.read_csv("survey_results_public.csv", index_col = 'Respondent')
# schema_df = pd.read_csv("survey_results_schema.csv",index_col='Column')

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3       8820.0
# 4      61000.0
# 5          NaN
# 6     366420.0
# 7          NaN
# 8          NaN
# 9      95179.0
# 10     13293.0
# 11         NaN
# 12         NaN
# 13     90000.0
# 14     57060.0
# 15         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_484\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize = True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group("India")
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
country_grp.get_group("Canada")
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 12                     I am a student who is learning to code       No
# 21                                I code primarily as a hobby      Yes
# 31                     I am a student who is learning to code       No
# 37                                I code primarily as a hobby      Yes
# ...                                                       ...      ...
# 69741                                                     NaN      Yes
# 75496                                                     NaN      Yes
# 82007                                                     NaN       No
# 85182                                                     NaN       No
# 88377                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
country_grp.get_group("Israel")
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 24                  I am a developer by profession      Yes
# 276                 I am a developer by profession       No
# 309         I am a student who is learning to code      Yes
# 328                 I am a developer by profession      Yes
# 334                 I am a developer by profession      Yes
# ...                                            ...      ...
# 88626                  I code primarily as a hobby      Yes
# 88755       I am a student who is learning to code      Yes
# 39449                                          NaN      Yes
# 39777                                          NaN      Yes
# 61787                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 24                                                      Never
# 276                                   Less than once per year
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt,'SocialMedia'].value_counts()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp["SocialMedia"].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: SocialMedia, Length: 1220, dtype: int64

# %%
country_grp["SocialMedia"].value_counts().loc["India"]
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp["SocialMedia"].value_counts().loc["Canada"]
# Out:
# SocialMedia
# Reddit                      901
# YouTube                     526
# Facebook                    515
# Twitter                     405
# Instagram                   246
# I don't use social media    232
# WhatsApp                    185
# LinkedIn                    179
# WeChat 微信                    44
# Snapchat                     28
# VK ВКонта́кте                 7
# Weibo 新浪微博                    1
# Name: SocialMedia, dtype: int64

# %%
country_grp["SocialMedia"].value_counts().loc["Pakistan"]
# Out:
# SocialMedia
# WhatsApp                    266
# Facebook                    232
# YouTube                     182
# LinkedIn                     71
# Twitter                      58
# Instagram                    41
# Reddit                       28
# I don't use social media     23
# Snapchat                      5
# Hello                         1
# VK ВКонта́кте                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp.median()
# Out:
#                                        CompTotal  ConvertedComp  WorkWeekHrs  \
# Country
# Afghanistan                              39000.0         6222.0         45.0
# Albania                                  65000.0        10818.0         40.0
# Algeria                                  55000.0         7878.0         40.0
# Andorra                                  76500.0       160931.0         42.0
# Angola                                  202000.0         7764.0         45.0
# ...                                          ...            ...          ...
# Venezuela, Bolivarian Republic of...      1000.0         6384.0         40.0
# Viet Nam                              15000000.0        11892.0         40.0
# Yemen                                   125000.0        11940.0         40.0
# Zambia                                    5000.0         5040.0         40.0
# Zimbabwe                                  1600.0        19200.0         46.5
#
# ...

# %%
country_grp["ConvertedComp"].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
country_grp["ConvertedComp"].aggregate(['median','mean','max','min','sum'])
# Out:
#                                         median           mean        max  \
# Country
# Afghanistan                             6222.0  101953.333333  1000000.0
# Albania                                10818.0   21833.700000   187668.0
# Algeria                                 7878.0   34924.047619  1000000.0
# Andorra                               160931.0  160931.000000   171862.0
# Angola                                  7764.0    7764.000000     7764.0
# ...                                        ...            ...        ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907   137484.0
# Viet Nam                               11892.0   17233.436782   140000.0
# Yemen                                  11940.0   16909.166667    60000.0
# Zambia                                  5040.0   10075.375000    40524.0
# Zimbabwe                               19200.0   34046.666667   180000.0
#
#                                            min        sum
# Country
# ...

# %%
country_grp["ConvertedComp"].aggregate(['median','mean','max','min','sum']).loc["India"]
# Out:
# median    1.008000e+04
# mean      2.805766e+04
# max       2.000000e+06
# min       0.000000e+00
# sum       1.122026e+08
# Name: India, dtype: float64

# %%
filt = df['Country'] == 'United States'
df.loc[filt,'LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 10083

# %%
country_grp["LanguageWorkedWith"].value_counts()
# Out:
# Country      LanguageWorkedWith
# Afghanistan  HTML/CSS;JavaScript;PHP;SQL                3
#              HTML/CSS;Java;JavaScript;PHP;Python;SQL    2
#              HTML/CSS;Java;PHP;SQL                      2
#              Python                                     2
#              Assembly                                   1
#                                                        ..
# Zimbabwe     HTML/CSS;Python;SQL                        1
#              Java;JavaScript;Kotlin;Python              1
#              Java;JavaScript;SQL                        1
#              Objective-C                                1
#              Python                                     1
# Name: LanguageWorkedWith, Length: 48114, dtype: int64

# %%
country_grp["LanguageWorkedWith"].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 country_grp["LanguageWorkedWith"].str.contains('Python').sum()
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains('Python').sum()/ len(x)*100)
# Out:
# Country
# Afghanistan                             18.181818
# Albania                                 26.744186
# Algeria                                 29.850746
# Andorra                                  0.000000
# Angola                                  40.000000
#                                           ...
# Venezuela, Bolivarian Republic of...    31.818182
# Viet Nam                                33.766234
# Yemen                                   15.789474
# Zambia                                  33.333333
# Zimbabwe                                35.897436
# Name: LanguageWorkedWith, Length: 179, dtype: float64

# %%
#Finding out what percentage of people use python in each country...

# %%
#1.
country_grp["LanguageWorkedWith"].apply(lambda x: len(x))
# Out:
# Country
# Afghanistan                              44
# Albania                                  86
# Algeria                                 134
# Andorra                                   7
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     88
# Viet Nam                                231
# Yemen                                    19
# Zambia                                   12
# Zimbabwe                                 39
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").sum()/ len(x)*100)
# Out:
# Country
# Afghanistan                             18.181818
# Albania                                 26.744186
# Algeria                                 29.850746
# Andorra                                  0.000000
# Angola                                  40.000000
#                                           ...
# Venezuela, Bolivarian Republic of...    31.818182
# Viet Nam                                33.766234
# Yemen                                   15.789474
# Zambia                                  33.333333
# Zimbabwe                                35.897436
# Name: LanguageWorkedWith, Length: 179, dtype: float64

# %%
#2.
country_respondents = df["Country"].value_counts()
country_respondents
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
country_python = country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").sum())
country_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents,country_python],axis = 'columns',sort = False)

# %%
python_df
# Out:
#                    Country  LanguageWorkedWith
# United States        20949               10083
# India                 9061                3105
# Germany               5866                2451
# United Kingdom        5737                2384
# Canada                3395                1558
# ...                    ...                 ...
# Tonga                    1                   0
# Timor-Leste              1                   1
# North Korea              1                   0
# Brunei Darussalam        1                   0
# Chad                     1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={"Country":'NumRespondents',"LanguageWorkedWith":'NumPython'},inplace = True)

# %%
python_df
# Out:
#                    NumRespondents  NumPython
# United States               20949      10083
# India                        9061       3105
# Germany                      5866       2451
# United Kingdom               5737       2384
# Canada                       3395       1558
# ...                           ...        ...
# Tonga                           1          0
# Timor-Leste                     1          1
# North Korea                     1          0
# Brunei Darussalam               1          0
# Chad                            1          0
#
# [179 rows x 2 columns]

# %%
python_df["PythonPercentage"] = (python_df['NumPython']/python_df['NumRespondents'])*100

# %%
python_df
# Out:
#                    NumRespondents  NumPython  PythonPercentage
# United States               20949      10083         48.131176
# India                        9061       3105         34.267741
# Germany                      5866       2451         41.783157
# United Kingdom               5737       2384         41.554820
# Canada                       3395       1558         45.891016
# ...                           ...        ...               ...
# Tonga                           1          0          0.000000
# Timor-Leste                     1          1        100.000000
# North Korea                     1          0          0.000000
# Brunei Darussalam               1          0          0.000000
# Chad                            1          0          0.000000
#
# [179 rows x 3 columns]

# %%
python_df["PythonPercentage"].loc["Yemen"]
# Out:
# 15.789473684210526

# %%
python_df.sort_values('PythonPercentage',ascending = False,inplace=True)

# %%
python_df.head(50)
# Out:
#                                   NumRespondents  NumPython  PythonPercentage
# Sao Tome and Principe                          1          1        100.000000
# Timor-Leste                                    1          1        100.000000
# Dominica                                       1          1        100.000000
# Niger                                          1          1        100.000000
# Turkmenistan                                   7          6         85.714286
# Mauritania                                     7          5         71.428571
# Guinea                                         3          2         66.666667
# Bahamas                                        3          2         66.666667
# Guyana                                         3          2         66.666667
# Uganda                                        72         47         65.277778
# Iceland                                       49         30         61.224490
# ...

# %% [markdown]
# **Cleaning Data - Casting DataTypes and Handling Missing Values**

# %%
na_vals = ['NA','Missing']
df = pd.read_csv("survey_results_public.csv", index_col = 'Respondent',na_values = na_vals)
pd.set_option("display.max_columns",85)

# %%
schema_df = pd.read_csv("survey_results_schema.csv",index_col='Column')
pd.set_option("display.max_rows",85)

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1       4
# 2     NaN
# 3       3
# 4       3
# 5      16
# 6      13
# 7       6
# 8       8
# 9      12
# 10     12
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 df['YearsCode'].astype('float')
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0, inplace =  True)
df['YearsCode'].replace('More than 50 years',51, inplace =  True)

# %%
df['YearsCode']=df['YearsCode'].astype('float')

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0
